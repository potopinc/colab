# %% [markdown]
# <a href="https://colab.research.google.com/github/potopinc/colab/blob/main/ML_3_self_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Практика по  NumPy
#
# Этот ноутбук представляет из себя  практическое задание.

# %% [markdown]
# В этом блоке нужно выполнить несколько простых упражнений на работу с векторами в numpy.
# Пишите код в ячейках после каждого задания. Для начала импортируйте библиотеку.

# %% [markdown]
# Ниже считывается файл с минимальными температурами по дням в период с 01.01.2003 по 25.09.2005 в г. Москва.

# %%
with open('weather_min.txt') as f:
  l = f.readlines()
l = np.array([temp[:-1] for temp in l[:-1]])
l = l[l != ''].astype(float)

# %% [markdown]
# # 1. Январь
# Выведите все значения температуры за январь 2003 года.

# %% [markdown]
# # 2. Последний день
# Измените температуру последнего дня на любое число.

# %% [markdown]
# # 3. Не люблю холода
# Замените все отрицательные температуры на положительные (не изменяя значения температур). Подсказка: np.abs().

# %% [markdown]
# #4. Удачное число
# Найдите индексы всех чисел равных 7. Подсказка: np.where().

# %% [markdown]
# # 5. Неудуачное число
# Замените все числа, кратные 13 или 4, на число 7.

# %% [markdown]
# #6. Статистика
# Найдите минимум, максимум, среднее значение и медиану.

# %% [markdown]
# # 7. Неповторимый
# Сколько уникальных значений температур содержит файл? Подсказка: np.unique().

# %% [markdown]
# # 8. Глобальное потепление
# Увеличьте значение температуры каждого дня на случайное число от 0 до 1 (случайные числа должны быть разными).

# %% [markdown]
# # Дополнительно

# %% [markdown]
# #### Задание 1.
#
# Создайте вектор из 100 чисел x = [1, ... , ... , ..., 137].
#
# len(x) == 100

# %% [markdown]
# #### Задание 2.
# Даны векторы
#
#
# `a = [1, 3, 7]`
#
# `b = [2, -1, 5]`
#
#
# Найдите скалярное произведение векторов **2a** и **-b**.

# %% [markdown]
# #### Задание 3*.
#
# Вам дан вектор *a* = [1, 2, 5, 10]
#
# Превратите вектор *a* в [0, 4, 0, 20] в одну строчку. Да, нужно угадать формулу.

# %% [markdown]
# #### Задание 4**.
# 1. Выбрать все чётные строки матрицы A.
# 2. Составить одномерный массив из всех не делящихся на 3 элементов нечетных столбцов А.
# 3. Посчитать сумму диагональных элементов A.

# %%
# пример превращения вектора в двумерную матрицу (таблицу)
A = np.arange(120).reshape(10, -1)
A

# %%
# Выбрать все четные строки матрицы A.

# %%
# Составить одномерный массив
# из всех не делящихся на 3 элементов нечетных столбцов А.

# %%
# Посчитать сумму диагональных элементов A.

# %% [markdown]
# # Не забудь сдать ноутбук с выполненным заданием!
